# %% [markdown]
# # Appendix: Benchmarking Solvers
#
# Benchmarks on simple test structures can be used for
# 1. Investigation of convergence of the classical tortuosity factor with increasing voxel count. This addresses [pixelation artifacts](https://iopscience.iop.org/article/10.1149/1945-7111/ad9a07).
# 2. Cross-validation between various solvers to check consistency and different wall-time and RAM scaling (`Solver`, `PeriodicSolver`, `AnisotropicSolver`, `MultiPhaseSolver`).
#
# In `utils.py`, various test structures are predefined which can directly be called by the `run_benchmark_study` function in `benchmark.py`. We first visualise the various test structures...

# %%
from taufactor.utils import create_fcc_cube, \
    create_stacked_blocks, create_2d_diagonals, \
    create_3d_diagonals, create_2d_zigzag
import matplotlib.pyplot as plt
import numpy as np

Nx = 16
fields = {}

fields["fcc"] = create_fcc_cube(Nx)
fields["blocks"] = create_stacked_blocks(Nx, features=1)
fields["2d_diagonals"] = create_2d_diagonals(Nx, features=1)
fields["2d_zigzag"] = create_2d_zigzag(Nx, features=1)
fields["3d_diagonals"] = create_3d_diagonals(Nx, features=1)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(15, 4), dpi=100)
for i, structure in enumerate(fields.keys()):
    axes[i].remove()
    axes[i] = fig.add_subplot(1, 5, i + 1, projection='3d')
    axes[i].voxels(np.transpose(fields[structure], (2,1,0))==1, facecolors='gray', edgecolor='black', alpha=1.0)
    axes[i].set_zlim(0, Nx)
    axes[i].set_aspect('equal')
    axes[i].set_title(structure)
    axes[i].set_xlim(0, Nx)
    axes[i].set_ylim(0, Nx)
plt.tight_layout()
plt.show()

# %% [markdown]
# It is also possible to create the ``blocks``, ``2d_diagonals``, ``2d_zigzag`` and ``3d_diagonals`` with multiple features in a repeating pattern e.g.

# %%
from taufactor.metrics import label_periodic
from scipy.ndimage import generate_binary_structure

fields = {}
features = 2
fields["blocks"] = create_stacked_blocks(Nx, features=features)
fields["2d_diagonals"] = create_2d_diagonals(Nx, features=features)
fields["2d_zigzag"] = create_2d_zigzag(Nx, features=features)
fields["3d_diagonals"] = create_3d_diagonals(Nx, features=features)

fields["blocks"][Nx//2:,:Nx//2,Nx//2:] *= 2
connectivity = generate_binary_structure(3, 1)
fields["2d_diagonals"] = label_periodic(fields["2d_diagonals"], 1, connectivity, periodic=(False, True, True))[0]
fields["2d_zigzag"] = label_periodic(fields["2d_zigzag"], 1, connectivity, periodic=(False, True, True))[0]
fields["3d_diagonals"] = label_periodic(fields["3d_diagonals"], 1, connectivity, periodic=(False, True, True))[0]

colors = ['white', 'gray', 'red', 'blue', 'green']
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 4), dpi=100)
for i, structure in enumerate(fields.keys()):
    axes[i].remove()
    axes[i] = fig.add_subplot(1, 5, i + 1, projection='3d')
    for j in np.unique(fields[structure]):
        if j>0:
            axes[i].voxels(np.transpose(fields[structure], (2,1,0))==j, facecolors=colors[j], edgecolor='black', alpha=1.0)
    axes[i].set_zlim(0, Nx)
    axes[i].set_aspect('equal')
    axes[i].set_title(structure)
    axes[i].set_xlim(0, Nx)
    axes[i].set_ylim(0, Nx)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tau Convergence vs. Voxel Count on FCC cube

# %%
from taufactor.benchmark import run_benchmark_study
import pandas as pd

Ns = [32, 64, 100, 128, 200, 256, 300]
res = run_benchmark_study(
    Ns=Ns,
    devices=['cuda'],
    conv_crit_values=[1e-3],
    structure='fcc',
    solver='Solver',
    write_file=False,
)

df_solver = pd.DataFrame(res).sort_values('N').reset_index(drop=True)
df_solver
# Out:
#      N structure  solver device  conv_crit  total_time  solve_time  \
# 0   32       fcc  Solver   cuda      0.001    0.265774    0.087083
# 1   64       fcc  Solver   cuda      0.001    0.124761    0.109387
# 2  100       fcc  Solver   cuda      0.001    0.283098    0.237355
# 3  128       fcc  Solver   cuda      0.001    0.965885    0.877250
# 4  200       fcc  Solver   cuda      0.001   12.079665   11.733507
# 5  256       fcc  Solver   cuda      0.001   33.535515   32.841498
# 6  300       fcc  Solver   cuda      0.001   64.579083   63.417038
#
#    iterations  taufactor  torch_init_max  torch_init_cur  torch_solve_max  \
# 0         400   3.307094        0.854528        0.354304         0.644096
# 1         500   2.348118        6.688768        2.723328         5.062144
# 2         800   2.184316       19.566592       10.246144        19.677696
# 3        1000   2.106697       36.183040       21.371392        40.163840
# 4        1500   2.029747      130.568192       81.554432       153.354752
# 5        2000   2.001894      270.534656      169.869312       320.798720
# 6        2400   1.984324      435.159040      273.418752       515.969536
#
#    torch_solve_cur
# 0         0.354304
# 1         2.723328
# 2        10.246144
# 3        21.371392
# 4        81.554432
# 5       169.869312
# 6       273.418752

# %%
fig, ax = plt.subplots(figsize=(5, 3), dpi=100)
x_voxels = df_solver['N'] ** 3
ax.plot(x_voxels, df_solver['taufactor'], marker='o', linewidth=2, color='#1f77b4', label='Solver')
ax.set_xscale('log')
ax.set_xlabel('voxels ($N^3$)')
ax.set_ylabel('$\\tau_\\text{classic}$')
ax.set_title('Tau vs. voxel count')
ax.grid(True, alpha=0.3)
ax.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Solver Cross-Comparison (Wall Time and RAM)

# %%
solver_specs = [
    {'solver': 'Solver', 'label': 'Solver', 'solver_kwargs': {}},
    {'solver': 'PeriodicSolver', 'label': 'PeriodicSolver', 'solver_kwargs': {}},
    {'solver': 'AnisotropicSolver', 'label': 'AnisotropicSolver', 'solver_kwargs': {'spacing': (1.0, 1.0, 1.0)}},
    {'solver': 'MultiPhaseSolver', 'label': 'MultiPhaseSolver', 'solver_kwargs': {}},
    {'solver': 'ElectrodeSolver', 'label': 'ElectrodeSolver', 'solver_kwargs': {}},
    {'solver': 'PeriodicElectrodeSolver', 'label': 'PeriodicElectrodeSolver', 'solver_kwargs': {}},
]

all_rows = []
for spec in solver_specs:
    print(f"Running {spec['label']}...")
    rows = run_benchmark_study(
        Ns=Ns,
        devices=['cuda'],
        conv_crit_values=[1e-3],
        structure='fcc',
        solver=spec['solver'],
        solver_kwargs=spec['solver_kwargs'],
        outfile='fcc_benchmark_results.txt',
        write_file=True,
    )
    for r in rows:
        r['solver_label'] = spec['label']
    all_rows.extend(rows)

df_compare = pd.DataFrame(all_rows)
# df_compare
# Out:
# Running Solver...
# Running PeriodicSolver...
# Running AnisotropicSolver...
# Running MultiPhaseSolver...
# Running ElectrodeSolver...
# Running PeriodicElectrodeSolver...

# %%
colors = {
    'Solver': "#05558f",
    'PeriodicSolver': "#3bc2da",
    'AnisotropicSolver': '#ff7f0e',
    'MultiPhaseSolver': '#d62728',
    'ElectrodeSolver': "#20830a",
    'PeriodicElectrodeSolver': "#25f012",
}
markers = {
    'Solver': 'x',
    'PeriodicSolver': 's',
    'AnisotropicSolver': '^',
    'MultiPhaseSolver': 'D',
    'ElectrodeSolver': 'o',
    'PeriodicElectrodeSolver': '*',
}
lines = {
    'Solver': '--',
    'PeriodicSolver': '-',
    'AnisotropicSolver': '-.',
    'MultiPhaseSolver': '-.',
    'ElectrodeSolver': '-',
    'PeriodicElectrodeSolver': '--',
}

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 4), dpi=200)
for label, g in df_compare.groupby('solver_label'):
    g = g.sort_values('N')
    x = g['N'] ** 3
    ax1.loglog(
        x, g['solve_time'], marker=markers.get(label, 'o'), linewidth=2,
        color=colors.get(label), label=label, linestyle=lines.get(label, '-')
    )
    ax2.loglog(
        x, g['torch_solve_max']/1024, marker=markers.get(label, 'o'), linewidth=2,
        color=colors.get(label), label=label, linestyle=lines.get(label, '-')
    )
    ax3.semilogx(
        x, g['taufactor'], marker=markers.get(label, 'o'), linewidth=2,
        color=colors.get(label), label=label, linestyle=lines.get(label, '-')
    )

# Hardware reference lines when using CUDA
for x, y, txt in [(3e4, 4, 'RTX 500 Ada (4 GB)'), (3e5, 48, 'RTX A6000 (48 GB)'), (3e6, 80, 'A100 (80 GB)')]:
    ax2.axhline(y, color='black', linestyle='--', linewidth=1)
    ax2.text(x, y, txt, fontsize=8, color='black')

ax1.set_xlabel('voxels ($N^3$)')
ax1.set_ylabel('wall time [s]')
ax1.set_title('Wall time scaling')
ax1.legend(loc='best', fontsize=8)
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('voxels ($N^3$)')
ax2.set_ylabel('RAM usage [GB]')
ax2.set_title('Max RAM scaling')
ax2.legend(loc='best', fontsize=8)
ax2.set_ylim(0.001, 150)
ax2.grid(True, alpha=0.3)

ax3.set_xlabel('voxels ($N^3$)')
ax3.set_ylabel('$\\tau_\\text{classic}$')
ax3.set_title('$\\tau_\\text{classic}$ convergence')
ax3.legend(loc='best', fontsize=8)
ax3.set_ylim(1.8, 3.8)
ax3.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
df_compare.groupby('solver_label', as_index=False).agg(
        wall_time_max_s=('solve_time', 'max'), ram_peak_MB=('torch_solve_max', 'max'),
    ).sort_values('wall_time_max_s')
# Out:
#               solver_label  wall_time_max_s  ram_peak_MB
# 0        AnisotropicSolver        63.180719   519.112192
# 5                   Solver        63.316393   515.969536
# 4           PeriodicSolver        64.259876   515.969536
# 1          ElectrodeSolver        71.503534   597.419520
# 3  PeriodicElectrodeSolver        72.319894   597.419520
# 2         MultiPhaseSolver        80.926540   922.217472

# %% [markdown]
# ## Multiphase Diffusivity Study

# %% [markdown]
# It is furthermore possible to create your own test geometries and run a benchmark study with them. To do so, you need to write a function and pass it to the benchmark study call. We combine this here with testing specifics of the multi-phase solver.

# %%
from taufactor.utils import create_2d_zigzag

def multi_zigzag(Nx):
    geom = create_2d_zigzag(Nx, features=1)
    N2 = Nx // 2
    geom[:N2, :, :][geom[:N2, :, :] == 1] = 2
    return geom

all_rows = []
diffusivities = [0.1, 0.5, 1.0, 2.0, 10.0]

for c in diffusivities:
    rows = run_benchmark_study(
        Ns=[64],
        solver='MultiPhaseSolver',
        solver_kwargs={'diffusivities': {0:0, 1: 1.0, 2: c}},
        structure=multi_zigzag,
        write_file=False,
    )
    for r in rows:
        r['diffusivity'] = c
    all_rows.extend(rows)

df_ratio = pd.DataFrame(all_rows).sort_values('diffusivity').reset_index(drop=True)
df_ratio
# Out:
#     N     structure            solver device  conv_crit  total_time  \
# 0  64  multi_zigzag  MultiPhaseSolver   cuda      0.001    0.264532
# 1  64  multi_zigzag  MultiPhaseSolver   cuda      0.001    0.110780
# 2  64  multi_zigzag  MultiPhaseSolver   cuda      0.001    0.086730
# 3  64  multi_zigzag  MultiPhaseSolver   cuda      0.001    0.103666
# 4  64  multi_zigzag  MultiPhaseSolver   cuda      0.001    0.134591
#
#    solve_time  iterations  taufactor  torch_init_max  torch_init_cur  \
# 0    0.237040         600   4.863461       12.312576        5.918208
# 1    0.096549         500   1.808737       12.312576        5.918208
# 2    0.072181         400   1.607159       12.312576        5.918208
# 3    0.089666         500   1.808737       12.312576        5.918208
# 4    0.120587         600   4.863412       12.312576        5.918208
#
#    torch_solve_max  torch_solve_cur  diffusivity
# 0         9.031168         5.918208          0.1
# 1         9.031168         5.918208          0.5
# 2         9.031168         5.918208          1.0
# 3         9.031168         5.918208          2.0
# 4         9.031168         5.918208         10.0

# %% [markdown]
# The results of this first study show that the tortuosity factor of multiphase simulations depends on the ratio of diffusivities/conductivities. When $D_a$ is kept at $1$ and $D_b\in[0.1, 0.5, 1.0, 2.0, 10.0]$, we observe a symmetry in $\tau_\text{c}$ values.
#
# In the next study, we create multiple diagonals, which are labelled as $1$ and $2$ (see the Figure above with grey and red features). Even though the effective diffusivity depends on the actual value of $D_b$, the tortuosity factor does not and is, in this case of parallel conducting channels, a purely geometric quantity.

# %%
from taufactor.utils import create_2d_diagonals

def multi_diagonal(Nx):
    geom = create_2d_diagonals(Nx, features=2)
    geom = label_periodic(geom, 1, connectivity, periodic=(False, True, True))[0]
    return geom

all_rows = []
diffusivities = [0.1, 0.5, 1.0, 2.0, 10.0]

for c in diffusivities:
    rows = run_benchmark_study(
        Ns=[64],
        solver='PeriodicMultiPhaseSolver',
        solver_kwargs={'diffusivities': {0:0, 1:1, 2:c, 3:1, 4:c}},
        structure=multi_diagonal,
        write_file=False,
    )
    for r in rows:
        r['diffusivity'] = c
    all_rows.extend(rows)

df_ratio = pd.DataFrame(all_rows).sort_values('diffusivity').reset_index(drop=True)
df_ratio
# Out:
#     N       structure                    solver device  conv_crit  total_time  \
# 0  64  multi_diagonal  PeriodicMultiPhaseSolver   cuda      0.001    0.337359
# 1  64  multi_diagonal  PeriodicMultiPhaseSolver   cuda      0.001    0.162466
# 2  64  multi_diagonal  PeriodicMultiPhaseSolver   cuda      0.001    0.190368
# 3  64  multi_diagonal  PeriodicMultiPhaseSolver   cuda      0.001    0.194166
# 4  64  multi_diagonal  PeriodicMultiPhaseSolver   cuda      0.001    0.143843
#
#    solve_time  iterations  taufactor  torch_init_max  torch_init_cur  \
# 0    0.295491         500   2.010120       12.312576        5.918208
# 1    0.141170         500   2.010121       12.312576        5.918208
# 2    0.166369         500   2.010121       12.312576        5.918208
# 3    0.162520         500   2.010121       12.312576        5.918208
# 4    0.120118         500   2.010119       12.312576        5.918208
#
#    torch_solve_max  torch_solve_cur  diffusivity
# 0         9.031168         5.918208          0.1
# 1         9.031168         5.918208          0.5
# 2         9.031168         5.918208          1.0
# 3         9.031168         5.918208          2.0
# 4         9.031168         5.918208         10.0

# %% [markdown]
# This multi-phase $\tau_\text{c}$ value of $2.01$ is identical to the result obtained with the ``PeriodicSolver`` and ``PeriodicMultiPhaseSolver`` for binary labelled channels (i.e. label 0 is isolating and label 1 has a diffusivity of $D=1$).

# %%
all_rows = []
for solver in ['PeriodicSolver', 'PeriodicMultiPhaseSolver']:
    res = run_benchmark_study(
        Ns=[64], solver=solver,
        structure='diagonal2d', features=2,
        write_file=False,
    )
    all_rows.extend(res)
df = pd.DataFrame(all_rows).sort_values('N').reset_index(drop=True)
df
# Out:
#     N   structure                    solver device  conv_crit  total_time  \
# 0  64  diagonal2d            PeriodicSolver   cuda      0.001    0.279071
# 1  64  diagonal2d  PeriodicMultiPhaseSolver   cuda      0.001    0.207014
#
#    solve_time  iterations  taufactor  torch_init_max  torch_init_cur  \
# 0    0.255504         500   2.010121        6.688768        2.723328
# 1    0.186902         500   2.010121       12.312576        5.918208
#
#    torch_solve_max  torch_solve_cur
# 0         5.062144         2.723328
# 1         9.031168         5.918208

# %% [markdown]
# ## Electrode benchmark case

# %% [markdown]
# Load example electrode structure and create custom geometry by taking sub-volumes

# %%
import tifffile
img = tifffile.imread('electrode.tiff')
labels = {"pore":0, "NMC":85, "CBD":170}

def electrode(Nx):
    return img[:Nx,:Nx,:Nx]

solver_specs = [
    {'solver': 'ElectrodeSolver', 'label': 'ElectrodeSolver', 'solver_kwargs': {'conductive_label': labels["pore"], 'reactive_label': labels["NMC"]}},
    {'solver': 'PeriodicElectrodeSolver', 'label': 'PeriodicElectrodeSolver', 'solver_kwargs': {'conductive_label': labels["pore"], 'reactive_label': labels["NMC"]}},
]

all_rows = []
for spec in solver_specs:
    print(f"Running {spec['label']}...")
    rows = run_benchmark_study(
        Ns=[32, 64, 128, 256],
        devices=['cuda'],
        conv_crit_values=[1e-3],
        structure=electrode,
        solver=spec['solver'],
        solver_kwargs=spec['solver_kwargs'],
        outfile='electrode_benchmark_results.txt',
        write_file=True,
    )
    for r in rows:
        r['solver_label'] = spec['label']
    all_rows.extend(rows)

df_compare = pd.DataFrame(all_rows)
df_compare
# Out:
# Running ElectrodeSolver...
# Running PeriodicElectrodeSolver...
#      N  structure                   solver device  conv_crit  total_time  \
# 0   32  electrode          ElectrodeSolver   cuda      0.001    0.150130
# 1   64  electrode          ElectrodeSolver   cuda      0.001    0.232672
# 2  128  electrode          ElectrodeSolver   cuda      0.001    1.297750
# 3  256  electrode          ElectrodeSolver   cuda      0.001   36.280062
# 4   32  electrode  PeriodicElectrodeSolver   cuda      0.001    0.230345
# 5   64  electrode  PeriodicElectrodeSolver   cuda      0.001    0.149168
# 6  128  electrode  PeriodicElectrodeSolver   cuda      0.001    1.239973
# 7  256  electrode  PeriodicElectrodeSolver   cuda      0.001   34.949208
#
#    solve_time  iterations  taufactor  torch_init_max  torch_init_cur  \
# 0    0.141812         600   2.689350        0.855552        0.354304
# 1    0.217147         500   1.787707        6.689792        2.723328
# 2    1.279131        1400   2.153119       36.184064       21.371392
# 3   36.227234        2200   2.072868      287.310848      169.869312
# 4    0.225415         600   1.982882        0.855552        0.354304
# 5    0.139330         500   1.638277        6.689792        2.723328
# 6    1.224691        1300   2.072309       36.184064       21.371392
# 7   34.895753        2100   2.007722      287.310848      169.869312
#
#    torch_solve_max  torch_solve_cur             solver_label
# 0         0.747520         0.354304          ElectrodeSolver
# 1         5.869056         2.723328          ElectrodeSolver
# 2        46.537216        21.371392          ElectrodeSolver
# 3       371.195904       169.869312          ElectrodeSolver
# 4         0.747520         0.354304  PeriodicElectrodeSolver
# 5         5.869056         2.723328  PeriodicElectrodeSolver
# 6        46.537216        21.371392  PeriodicElectrodeSolver
# 7       371.195904       169.869312  PeriodicElectrodeSolver
